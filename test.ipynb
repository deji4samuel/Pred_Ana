# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
test_data = pd.read_csv('Data/final_model_dataset.csv')

# %%
test_data.head()
# Out:
#          date region_id operator  subscribers  active_users  data_usage_gb  \
# 0  2021-01-31        R1      MTN       148984        126636   7.380823e+05
# 1  2021-02-28        R1      MTN       748663        636363   1.159888e+06
# 2  2021-03-31        R1      MTN       686146        583224   2.881433e+06
# 3  2021-04-30        R1      MTN       728776        619459   3.426966e+06
# 4  2021-05-31        R1      MTN       938688        797884   1.616847e+06
#
#    avg_data_per_user   call_minutes  sms_count  churn_rate      arpu  \
# 0           4.954104  147616.454354      44695    0.040890  4.391010
# 1           1.549279  231977.629619     224598    0.017954  7.979394
# 2           4.199446  576286.644308     205843    0.012962  5.509260
# 3           4.702359  685393.256753     218632    0.044002  6.146155
# 4           1.722454  323369.422499     281606    0.022439  5.276283
#
#   network_type    state  latitude  longitude  population  population_density  \
# ...

# %%
test_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   date                   240 non-null    str
#  1   region_id              240 non-null    str
#  2   operator               240 non-null    str
#  3   subscribers            240 non-null    int64
#  4   active_users           240 non-null    int64
#  5   data_usage_gb          240 non-null    float64
#  6   avg_data_per_user      240 non-null    float64
#  7   call_minutes           240 non-null    float64
#  8   sms_count              240 non-null    int64
#  9   churn_rate             240 non-null    float64
#  10  arpu                   240 non-null    float64
#  11  network_type           240 non-null    str
#  12  state                  240 non-null    str
#  13  latitude               240 non-null    float64
#  14  longitude              240 non-null    float64
# ...

# %%
test_data.shape
# Out:
# (240, 20)

# %%
test_data.describe()
# Out:
#          subscribers   active_users  data_usage_gb  avg_data_per_user  \
# count     240.000000     240.000000   2.400000e+02         240.000000
# mean   565763.016667  480898.112500   1.873397e+06           3.265533
# std    265411.217363  225599.547249   1.105677e+06           1.019632
# min    100404.000000   85343.000000   1.704171e+05           1.509083
# 25%    319689.250000  271735.250000   9.348769e+05           2.300658
# 50%    583344.000000  495842.000000   1.712755e+06           3.324271
# 75%    762517.000000  648138.750000   2.699036e+06           4.113577
# max    998613.000000  848821.000000   4.686930e+06           4.989060
#
#         call_minutes      sms_count  churn_rate        arpu    latitude  \
# count     240.000000     240.000000  240.000000  240.000000  240.000000
# mean   374679.313406  169728.462500    0.029860    6.408172    9.640957
# std    221135.491734   79623.377497    0.011374    2.022631    2.101979
# ...

# %%
test_data['operator'].value_counts()
# Out:
# operator
# MTN    240
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(10, 6))
ax.hist(test_data['broadband_penetration'], bins=30, color='blue', alpha=0.7)
ax.set_xlabel('Broadband Penetration')
ax.set_ylabel('Frequency')
ax.set_title('Distribution of Broadband Penetration')
# Out:
# Text(0.5, 1.0, 'Distribution of Broadband Penetration')

# %%
test_data['network_type'].value_counts()
# Out:
# network_type
# 4G    240
# Name: count, dtype: int64
